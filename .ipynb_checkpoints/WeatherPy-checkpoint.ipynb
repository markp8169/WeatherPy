# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
name = []
lat = []
long = []
country = []
date =[]
temp = []
wind = []
cloud = []
humid = []

# %%
# Loop through the cities and request data on each
city_number = 0
error_number = 0

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        humid.append(response['main']['humidity'])

        # Create and print city number with its associated city
        city_number += 1
        print(f"({city_number}): {city}")
        
    except KeyError:
        
        # Create and print error number with its associated city
        error_number += 1
        print(f"ERROR {error_number}: {city}")
        
        # Pulls 1 request per second from API  
        time.sleep(1.1)
    
# Print a summary of for-loop
print("----------------------------")
print(f"{city_number} cities successfully logged")
print(f"{error_number} errors returned")
# Out:
# (1): port alfred
# (2): vestmannaeyjar
# (3): kruisfontein
# (4): ushuaia
# ERROR 1: tucuma
# (5): changji
# (6): mataura
# (7): ponta do sol
# (8): carnarvon
# (9): busselton
# (10): airai
# (11): mar del plata
# (12): atuona
# (13): bluff
# (14): namibe
# (15): christchurch
# ERROR 2: barbar
# (16): saint george
# (17): torbay
# (18): mahebourg
# (19): san patricio
# (20): kapaa
# (21): gunjur
# (22): pangnirtung
# (23): inuvik
# ERROR 3: tumannyy
# ERROR 4: illoqqortoormiut
# (24): dikson
# (25): barrow
# (26): vitim
# (27): cherskiy
# (28): qaanaaq
# (29): inongo
# (30): lebu
# (31): thompson
# (32): portland
# (33): zhongshu
# (34): punta arenas
# (35): arraial do cabo
# (36): rikitea
# (37): pontes e lacerda
# (38): mehamn
# (39): bredasdorp
# (40): saskylakh
# (41): saint-augustin
# (42): albany
# (43): vaini
# (44): ilulissat
# (45): fairbanks
# ERROR 5: anar darreh
# (46): bongaigaon
# (47): nome
# (48): svetlaya
# (49): mashhad
# (50): new norfolk
# (51): souillac
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from information
weather_dict = {"City": name, "Lat": lat, "Lng": long, "Country": country,
                "Date": date, "Max Temp": temp, "Wind Speed": wind,
                "Cloud Cover": cloud, "Humidity": humid}

weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#              City    Lat     Lng Country        Date  Max Temp  Wind Speed  \
# 0     Port Alfred -33.59   26.89      ZA  1540685923     67.78       14.14
# 1  Vestmannaeyjar  63.44  -20.27      IS  1540685923     40.42       29.57
# 2    Kruisfontein -34.00   24.73      ZA  1540685912     62.83       13.24
# 3         Ushuaia -54.81  -68.31      AR  1540681200     48.20       10.29
# 4         Changji  32.07  116.17      CN  1540685925     54.33        8.43
# 5         Mataura -46.19  168.86      NZ  1540685925     52.26        5.75
# 6    Ponta do Sol -20.63  -46.00      BR  1540685925     69.94        8.88
# 7       Carnarvon -30.97   22.13      ZA  1540685926     57.12        2.17
# 8       Busselton -33.64  115.35      AU  1540685926     59.14       10.78
# 9           Airai  -8.93  125.41      TL  1540685926     81.55        2.06
#
#    Cloud Cover  Humidity
# 0            0        95
# 1          100       100
# 2            0        85
# 3           40        76
# ...

# %%
# Save weather dataframe as .csv
weather_data.to_csv("weather_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, temp, marker="o", facecolors="red", edgecolors="black", alpha = 0.5)

plt.grid()
plt.title("City Latitude vs. Max Temperature (F) (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("Temperature.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humid, marker="o", facecolors="green", edgecolors="black", alpha = 0.5)

plt.grid()
plt.title("City Latitude vs. Humidity (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloud, marker="o", facecolors="orange", edgecolors="black", alpha = 0.5)

plt.grid()
plt.title("City Latitude vs. Cloudiness (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Clouds (%)")
plt.savefig("Clouds.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind, marker="o", facecolors="yellow", edgecolors="black", alpha = 0.5)

plt.grid()
plt.title("City Latitude vs. Wind Speed (10/27/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("Wind.png")

plt.show()
